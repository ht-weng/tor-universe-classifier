# %%
import pandas as pd
import numpy as np
import re
import json
import matplotlib.pyplot as plt
import glob, os, csv

from langdetect import detect

import gensim
from gensim.utils import simple_preprocess
from gensim import corpora, models
from gensim.models import CoherenceModel

from pprint import pprint

import nltk
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'http', 'javascript'])

from bs4 import BeautifulSoup

import pyLDAvis
import pyLDAvis.gensim

# import stanza
# # stanza.download('en')
# nlp = stanza.Pipeline('en', processors='tokenize,mwt,pos,lemma')

# %%
# Convert html file to title and body texts
def body2text(file):
    html = open(file, "rb")
    soup = BeautifulSoup(html, "html.parser")
    body = []
    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()

    text = soup.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    
    for line in lines:
        if line:
            body.append(line)
    title = soup.title
    if title is None:
        title_text = None
    else:
        title_text = title.string
    html.close()
    
    return [title_text, body]

# %%
# convert html to string
def body2text_body(html):
    soup = BeautifulSoup(html)
    result = []
    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()

    text = soup.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    for line in lines:
        if line:
            result.append(line)

    return result

# %%
stemmer = PorterStemmer()
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text))

def preprocess(sentences):
    result = []
    
    for sent in sentences:
        lemmas = []
        # tokenize
        tokens = gensim.utils.simple_preprocess(sent)
        for token in tokens:
            lemma = lemmatize_stemming(token)
            # remove stopwords
            if lemma not in stop_words:
                lemmas.append(lemma)
        # POS tagging
        nltk_tagged = nltk.pos_tag(lemmas)
        for word, tag in nltk_tagged:
            # only keep nouns
            if tag.startswith('N'):
                result.append(word)
    return result

# %%
def language_detect(ls):
    text = ' '.join(ls)
    result = detect(text)
    return result

# %%
def get_cluster_name(x, y):
    return x[y]

def custom_strip(x):
    return x.strip().strip('\n\t')

# %%
def most_frequent(List): 
    counter = 0
    num = List[0] 
      
    for i in List: 
        curr_frequency = List.count(i) 
        if(curr_frequency> counter): 
            counter = curr_frequency 
            num = i 
  
    return num

# %%
# Produce trainset

# %%
# Import labelled urls
df_url_labelled = pd.read_excel('../data/DUTA_10K.xls')
df_url_labelled.drop(columns='Unnamed: 0', inplace=True)
df_url_labelled

# %%
# Import all the crawled html files
df_html_ls = []

path = '../data/universe-labelled/'
all_files = glob.glob(os.path.join(path, '*.html'))

for filename in all_files:
    url = filename.strip('.html').replace(path, '')
    title_text = body2text(filename)
    title = title_text[0]
    text = title_text[1]
    tup = [url, title, text]
    df_html_ls.append(tup)

df_html = pd.DataFrame(df_html_ls, columns=['url', 'title', 'body_text'])
df_html

# %%
# Remove dead urls
df_html = df_html[df_html['body_text'].str.len() != 0]
df_html

# %%
df_train = pd.merge(left=df_html, right=df_url_labelled, left_on='url', right_on='Onion_Address')
df_train.drop(columns='Onion_Address', inplace=True)
df_train.rename(columns={"url": "url", "body_text": "body_text", "Main_Class": "main_class", 
                        "Sub_Class": "sub_class", "lang": "language"}, inplace=True)
# preprocess
df_train['body_token'] = df_train['body_text'].map(preprocess)
df_train = df_train[df_train['body_token'].str.len() != 0]

df_train

# %%
df_train_eng = df_train[df_train['language'] == 'en']
df_train_eng

# %%
df_train_noneng = df_train[df_train['language'] != 'en']
df_train_noneng

# %%
# Produce testset

# %%
# read in the urls with titles and htmls
df_url = pd.read_csv('../data/universe-url-sample.csv', index_col=None, lineterminator='\n')
df_url.drop(columns=['Unnamed: 0'], inplace=True)
df_url
# Out:
#                                                      url  \
# 0                                 2zljltoqfdkqcdmf.onion
# 1                                 4zyfu5qr3xg66ape.onion
# 2      6wlf4cyhq4u6rlqzngh3g6qrun4l3sf6yf54ez7eo2547k...
# 3      6khquuorwuucomnxp5egqfolpeddgjfbacpxyrjkbgftng...
# 4      5oesgn7p2zu6wpaavujjpold2sccpu7oia4afp24adujzt...
# ...                                                  ...
# 14660  3qr37zaumlym2jhcwkkqrarihdze2zp2xmmer4btkfqjrn...
# 14661  greenegbqkyk3ois.onion/wp-content/uploads/2020...
# 14662  greenegbqkyk3ois.onion/wp-content/plugins/cont...
# 14663  ctulnc6kyxkgt7fg.onion/carder-forum/14886-easy...
# 14664  akaoxb4ek4hm7vau.onion/offtopic/4186-silver-an...
#
#                                                 title  \
# 0                                         Light Money
# 1                                          Black Shop
# 2                                         CHEAP EUROS
# 3            Walt Cards - Gift Card seller since 2013
# 4                                         Light Money
# ...                                               ...
# 14660                                             NaN
# 14661                                             NaN
# 14662                                             NaN
# 14663          Easy ways to earn money as a teenager
# 14664  Silver-Angels - Kira &raquo; Biertamente onion
#
#                                                     body status  \
# 0      <!doctype html>\n<html>\n\n<head>\n    <meta c...   live
# 1      <!DOCTYPE html>\n<head>\n    <meta charset="ut...   live
# 2      <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...   live
# 3      <!DOCTYPE html>\r\n<html>\r\n\t<!-- Mirrored f...   live
# 4      <!doctype html>\n<html>\n\n<head>\n    <meta c...   live
# ...                                                  ...    ...
# 14660  !function(n){window.isEditMode=!1,n(window).on...   live
# 14661                                               ����   live
# 14662  .wpcf7 .screen-reader-response {\n\tposition: ...   live
# 14663  <!DOCTYPE html>\n<html lang="en">\n\t<head>\n\...   live
# 14664  <!DOCTYPE html>\n<html lang="ru">\n<head>\n\t<...   live
#
#                                  time  \
# 0      2020-09-29T03:31:47.370962464Z
# 1       2020-09-29T03:31:47.79917865Z
# 2       2020-09-29T03:31:47.85466791Z
# 3       2020-09-29T03:31:46.54407746Z
# 4      2020-09-29T03:31:46.748995354Z
# ...                               ...
# 14660  2020-09-30T02:09:56.213964118Z
# 14661  2020-09-30T02:10:00.029866451Z
# 14662  2020-09-30T02:09:59.250307811Z
# 14663  2020-09-30T02:09:56.863479772Z
# 14664   2020-09-30T02:09:34.87588546Z
#
#                                                   domain
# 0                                       2zljltoqfdkqcdmf
# 1                                       4zyfu5qr3xg66ape
# 2      6wlf4cyhq4u6rlqzngh3g6qrun4l3sf6yf54ez7eo2547k...
# 3      6khquuorwuucomnxp5egqfolpeddgjfbacpxyrjkbgftng...
# 4      5oesgn7p2zu6wpaavujjpold2sccpu7oia4afp24adujzt...
# ...                                                  ...
# 14660  3qr37zaumlym2jhcwkkqrarihdze2zp2xmmer4btkfqjrn...
# 14661                                   greenegbqkyk3ois
# 14662                                   greenegbqkyk3ois
# 14663                                   ctulnc6kyxkgt7fg
# 14664                                   akaoxb4ek4hm7vau
#
# [14665 rows x 6 columns]

# %%
# convert html to string
df_url = df_url[df_url['title'].notna()]
df_url.drop(columns=['status', 'time'], inplace=True)
# df_url = df_url[['url', 'title', 'body', 'domain']]
df_url = df_url[df_url['body'].str.len() != 0]
df_url['body_text'] = df_url['body'].map(body2text_body)

df_url
# Out:
# /home/mwsb/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/mwsb/.local/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/mwsb/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#                                                      url  \
# 0                                 2zljltoqfdkqcdmf.onion
# 1                                 4zyfu5qr3xg66ape.onion
# 2      6wlf4cyhq4u6rlqzngh3g6qrun4l3sf6yf54ez7eo2547k...
# 3      6khquuorwuucomnxp5egqfolpeddgjfbacpxyrjkbgftng...
# 4      5oesgn7p2zu6wpaavujjpold2sccpu7oia4afp24adujzt...
# ...                                                  ...
# 14656                  hi6puvkvistna6us.onion/Order4.php
# 14657  imperi2m2v2ebxey.onion/products/master/prepaid...
# 14658           uozu643uzpijef7f.onion/BuyMoneyGram3.php
# 14663  ctulnc6kyxkgt7fg.onion/carder-forum/14886-easy...
# 14664  akaoxb4ek4hm7vau.onion/offtopic/4186-silver-an...
#
#                                                    title  \
# 0                                            Light Money
# 1                                             Black Shop
# 2                                            CHEAP EUROS
# 3               Walt Cards - Gift Card seller since 2013
# 4                                            Light Money
# ...                                                  ...
# 14656  SELL CREDIT CARD & Transer WESTERN UNION & Tra...
# 14657  Prepaid Credit Card MasterCard X1 - Imperial S...
# 14658  Transfer MONEYGRAM & PAYPAL ACCOUNT & DUMPS & ...
# 14663             Easy ways to earn money as a teenager
# 14664     Silver-Angels - Kira &raquo; Biertamente onion
#
#                                                     body  \
# 0      <!doctype html>\n<html>\n\n<head>\n    <meta c...
# 1      <!DOCTYPE html>\n<head>\n    <meta charset="ut...
# 2      <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 3      <!DOCTYPE html>\r\n<html>\r\n\t<!-- Mirrored f...
# 4      <!doctype html>\n<html>\n\n<head>\n    <meta c...
# ...                                                  ...
# 14656  <!DOCTYPE html>\r\n<html><head>\r\n<meta http-...
# 14657  <!DOCTYPE html>\n<html class="nojs html css_ve...
# 14658  <!DOCTYPE html>\r\n<html lang="en">\r\n\r\n<he...
# 14663  <!DOCTYPE html>\n<html lang="en">\n\t<head>\n\...
# 14664  <!DOCTYPE html>\n<html lang="ru">\n<head>\n\t<...
#
#                                                   domain  \
# 0                                       2zljltoqfdkqcdmf
# 1                                       4zyfu5qr3xg66ape
# 2      6wlf4cyhq4u6rlqzngh3g6qrun4l3sf6yf54ez7eo2547k...
# 3      6khquuorwuucomnxp5egqfolpeddgjfbacpxyrjkbgftng...
# 4      5oesgn7p2zu6wpaavujjpold2sccpu7oia4afp24adujzt...
# ...                                                  ...
# 14656                                   hi6puvkvistna6us
# 14657                                   imperi2m2v2ebxey
# 14658                                   uozu643uzpijef7f
# 14663                                   ctulnc6kyxkgt7fg
# 14664                                   akaoxb4ek4hm7vau
#
#                                                body_text
# 0      [Light Money, Discount, FAQ, Proofs, Contact, ...
# 1      [Black Shop, Home, Services, Pricing, Black Sh...
# 2      [CHEAP EUROS, INFO, High quality 20EUR bills w...
# 3             [Walt Cards - Gift Card seller since 2013]
# 4      [Light Money, Discount, FAQ, Proofs, Contact, ...
# ...                                                  ...
# 14656  [SELL CREDIT CARD & Transer WESTERN UNION & Tr...
# 14657  [Prepaid Credit Card MasterCard X1 - Imperial ...
# 14658  [Transfer MONEYGRAM & PAYPAL ACCOUNT & DUMPS &...
# 14663  [Easy ways to earn money as a teenager, REGIST...
# 14664  [Silver-Angels - Kira » Biertamente onion, All...
#
# [10702 rows x 5 columns]

# %%
# group urls, titles and body texts by domain
df_test = df_url.groupby('domain').agg(list)
df_test.reset_index(inplace=True)
df_test.drop(columns=['body'], inplace=True)
# df_test = df_test[['domain', 'url', 'title', 'body_text']]
df_test['body_text'] = df_test['body_text'].apply(lambda x: [z for y in x for z in y])

df_test
# Out:
#                                                  domain  \
# 0                                    2.weedmetoas22rdij
# 1                                      2222222222gwddfp
# 2                                      2222222222vf2a2e
# 3     222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjqr...
# 4                                      22222222dldy4lh7
# ...                                                 ...
# 7650                                   zsolxunfmbfuq7wf
# 7651                                   zuvv2pd5znhhz47d
# 7652  zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq45...
# 7653  zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vhe...
# 7654                                   zxterqgdopw2tayp
#
#                                                     url  \
# 0                            [2.weedmetoas22rdij.onion]
# 1                              [2222222222gwddfp.onion]
# 2                              [2222222222vf2a2e.onion]
# 3     [222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjq...
# 4                              [22222222dldy4lh7.onion]
# ...                                                 ...
# 7650                           [zsolxunfmbfuq7wf.onion]
# 7651                           [zuvv2pd5znhhz47d.onion]
# 7652  [zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq4...
# 7653  [zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vh...
# 7654                           [zxterqgdopw2tayp.onion]
#
#                                                   title  \
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoins!]
# 2                [FREECITY - Anonymous Escrow Platform]
# 3     [Best Financial Market, Proofs, VISA Gift Card...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7650    [mail.riseup.net :: Welcome to mail.riseup.net]
# 7651  [money house: trusted, automatic Visa credit c...
# 7652         [Shop cloned cards, paypal, western union]
# 7653  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7654                                   [Cc shop online]
#
#                                               body_text
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoin...
# 2     [FREECITY - Anonymous Escrow Platform, Please ...
# 3     [Best Financial Market, × Blockonomics        ...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7650  [mail.riseup.net :: Welcome to mail.riseup.net...
# 7651  [money house: trusted, automatic Visa credit c...
# 7652  [Shop cloned cards, paypal, western union, CLO...
# 7653  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7654  [Cc shop online, REGISTER IN CC/DUMP SHOP>>>>>...
#
# [7655 rows x 4 columns]

# %%
# preprocess
df_test['body_token'] = df_test['body_text'].map(preprocess)
df_test = df_test[df_test['body_token'].str.len() != 0]
df_test['title_token'] = df_test['title'].map(preprocess)

# detect language
df_test['language'] = df_test['body_token'].map(language_detect)
# df_test['language'] = df_test['title_token'].map(language_detect)
df_test.reset_index(inplace=True)
df_test.drop(columns='index' ,inplace=True)

df_test
# Out:
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/mwsb/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                  domain  \
# 0                                    2.weedmetoas22rdij
# 1                                      2222222222gwddfp
# 2                                      2222222222vf2a2e
# 3     222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjqr...
# 4                                      22222222dldy4lh7
# ...                                                 ...
# 7648                                   zsolxunfmbfuq7wf
# 7649                                   zuvv2pd5znhhz47d
# 7650  zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq45...
# 7651  zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vhe...
# 7652                                   zxterqgdopw2tayp
#
#                                                     url  \
# 0                            [2.weedmetoas22rdij.onion]
# 1                              [2222222222gwddfp.onion]
# 2                              [2222222222vf2a2e.onion]
# 3     [222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjq...
# 4                              [22222222dldy4lh7.onion]
# ...                                                 ...
# 7648                           [zsolxunfmbfuq7wf.onion]
# 7649                           [zuvv2pd5znhhz47d.onion]
# 7650  [zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq4...
# 7651  [zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vh...
# 7652                           [zxterqgdopw2tayp.onion]
#
#                                                   title  \
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoins!]
# 2                [FREECITY - Anonymous Escrow Platform]
# 3     [Best Financial Market, Proofs, VISA Gift Card...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7648    [mail.riseup.net :: Welcome to mail.riseup.net]
# 7649  [money house: trusted, automatic Visa credit c...
# 7650         [Shop cloned cards, paypal, western union]
# 7651  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7652                                   [Cc shop online]
#
#                                               body_text  \
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoin...
# 2     [FREECITY - Anonymous Escrow Platform, Please ...
# 3     [Best Financial Market, × Blockonomics        ...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7648  [mail.riseup.net :: Welcome to mail.riseup.net...
# 7649  [money house: trusted, automatic Visa credit c...
# 7650  [Shop cloned cards, paypal, western union, CLO...
# 7651  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7652  [Cc shop online, REGISTER IN CC/DUMP SHOP>>>>>...
#
#                                              body_token  \
# 0     [weed, cannabi, shop, express, ship, home, sho...
# 1     [bitcoin, gener, exploit, bitcoin, time, limit...
# 2                     [anonym, escrow, platform, pleas]
# 3     [financi, market, pay, btc, pay, exactli, btc,...
# 4     [hour, servic, anonym, hour, multipli, bitcoin...
# ...                                                 ...
# 7648  [mail, riseup, net, welcom, mail, riseup, net,...
# 7649  [money, trust, automat, visa, credit, card, ma...
# 7650  [shop, clone, card, paypal, union, clone, card...
# 7651  [onionwallet, anonym, secur, bitcoin, wallet, ...
# 7652  [cc, shop, onlin, regist, cc, dump, shop, cc, ...
#
#                                             title_token language
# 0                  [weed, cannabi, shop, express, ship]       en
# 1                    [bitcoin, gener, exploit, bitcoin]       en
# 2                            [anonym, escrow, platform]       en
# 3     [financi, market, proof, gift, card, imperi, s...       en
# 4                                [hour, servic, anonym]       en
# ...                                                 ...      ...
# 7648     [mail, riseup, net, welcom, mail, riseup, net]       en
# 7649  [money, trust, automat, visa, credit, card, ma...       en
# 7650                 [shop, clone, card, paypal, union]       en
# 7651  [onionwallet, anonym, secur, bitcoin, wallet, ...       en
# 7652                                  [cc, shop, onlin]       en
#
# [7653 rows x 7 columns]

# %%
df_test['url_array'] = df_test['url'].apply(lambda x: np.array(x))
df_test['name_index'] = df_test['url_array'].apply(lambda x: np.argmin(x))
df_test['cluster_name'] = df_test.apply(lambda x: get_cluster_name(x['title'], x['name_index']), axis=1)
df_test['cluster_name'] = df_test['cluster_name'].apply(lambda x: custom_strip(x))
df_test.drop(columns=['url_array', 'name_index'], inplace=True)
df_test
# Out:
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/mwsb/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/mwsb/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                  domain  \
# 0                                    2.weedmetoas22rdij
# 1                                      2222222222gwddfp
# 2                                      2222222222vf2a2e
# 3     222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjqr...
# 4                                      22222222dldy4lh7
# ...                                                 ...
# 7648                                   zsolxunfmbfuq7wf
# 7649                                   zuvv2pd5znhhz47d
# 7650  zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq45...
# 7651  zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vhe...
# 7652                                   zxterqgdopw2tayp
#
#                                                     url  \
# 0                            [2.weedmetoas22rdij.onion]
# 1                              [2222222222gwddfp.onion]
# 2                              [2222222222vf2a2e.onion]
# 3     [222222222xn2ozdb2mjnkjrvcopf5thb6la6yj24jvyjq...
# 4                              [22222222dldy4lh7.onion]
# ...                                                 ...
# 7648                           [zsolxunfmbfuq7wf.onion]
# 7649                           [zuvv2pd5znhhz47d.onion]
# 7650  [zw5snxarvt66el3ej5rdjjzk7frgf5tvk2enwc3yx2qq4...
# 7651  [zwf5i7hiwmffq2bl7euedg6y5ydzze3ljiyrjmm7o42vh...
# 7652                           [zxterqgdopw2tayp.onion]
#
#                                                   title  \
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoins!]
# 2                [FREECITY - Anonymous Escrow Platform]
# 3     [Best Financial Market, Proofs, VISA Gift Card...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7648    [mail.riseup.net :: Welcome to mail.riseup.net]
# 7649  [money house: trusted, automatic Visa credit c...
# 7650         [Shop cloned cards, paypal, western union]
# 7651  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7652                                   [Cc shop online]
#
#                                               body_text  \
# 0     [Weed Me - Cannabis Weed Shop | UPS Express Sh...
# 1     [Bitcoin Generator Exploit - Make Free Bitcoin...
# 2     [FREECITY - Anonymous Escrow Platform, Please ...
# 3     [Best Financial Market, × Blockonomics        ...
# 4     [100x Your Coins in 24 Hours - Officially Hidd...
# ...                                                 ...
# 7648  [mail.riseup.net :: Welcome to mail.riseup.net...
# 7649  [money house: trusted, automatic Visa credit c...
# 7650  [Shop cloned cards, paypal, western union, CLO...
# 7651  [OnionWallet Anonymous and secure Bitcoin Wall...
# 7652  [Cc shop online, REGISTER IN CC/DUMP SHOP>>>>>...
#
#                                              body_token  \
# 0     [weed, cannabi, shop, express, ship, home, sho...
# 1     [bitcoin, gener, exploit, bitcoin, time, limit...
# 2                     [anonym, escrow, platform, pleas]
# 3     [financi, market, pay, btc, pay, exactli, btc,...
# 4     [hour, servic, anonym, hour, multipli, bitcoin...
# ...                                                 ...
# 7648  [mail, riseup, net, welcom, mail, riseup, net,...
# 7649  [money, trust, automat, visa, credit, card, ma...
# 7650  [shop, clone, card, paypal, union, clone, card...
# 7651  [onionwallet, anonym, secur, bitcoin, wallet, ...
# 7652  [cc, shop, onlin, regist, cc, dump, shop, cc, ...
#
#                                             title_token language  \
# 0                  [weed, cannabi, shop, express, ship]       en
# 1                    [bitcoin, gener, exploit, bitcoin]       en
# 2                            [anonym, escrow, platform]       en
# 3     [financi, market, proof, gift, card, imperi, s...       en
# 4                                [hour, servic, anonym]       en
# ...                                                 ...      ...
# 7648     [mail, riseup, net, welcom, mail, riseup, net]       en
# 7649  [money, trust, automat, visa, credit, card, ma...       en
# 7650                 [shop, clone, card, paypal, union]       en
# 7651  [onionwallet, anonym, secur, bitcoin, wallet, ...       en
# 7652                                  [cc, shop, onlin]       en
#
#                                            cluster_name
# 0     Weed Me - Cannabis Weed Shop | UPS Express Shi...
# 1       Bitcoin Generator Exploit - Make Free Bitcoins!
# 2                  FREECITY - Anonymous Escrow Platform
# 3                                 Best Financial Market
# 4     100x Your Coins in 24 Hours - Officially Hidde...
# ...                                                 ...
# 7648      mail.riseup.net :: Welcome to mail.riseup.net
# 7649  money house: trusted, automatic Visa credit ca...
# 7650           Shop cloned cards, paypal, western union
# 7651  OnionWallet Anonymous and secure Bitcoin Walle...
# 7652                                     Cc shop online
#
# [7653 rows x 8 columns]

# %%
# Groupby domain name
df_test = df_test.groupby('cluster_name').agg({'domain': list, 'url': 'sum', 'title': 'sum', 'body_text': 'sum', 
                                             'body_token': 'sum', 'title_token': 'sum', 'language': list})
df_test.reset_index(inplace=True)
df_test
# Out:
#                                            cluster_name  \
# 0                                      ! CLONED CARDS !
# 1                       $$ The Green Machine $$ - Error
# 2     $$$ Credit Cards | PayPal | Wester Union | Mon...
# 3     &#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&#...
# 4     &lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dres...
# ...                                                 ...
# 1330                                                淡路島
# 1331                                          约伊兹的萌狼乡手札
# 1332                                               茶马古道
# 1333                    藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉
# 1334               ��� ����� � ������� - The Front Page
#
#                                                  domain  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                                    [he22pncoselnm54h]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                                    [darkfailllnkf4vf]
# 4                                    [rvy6qmlqfstv6rlz]
# ...                                                 ...
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1331  [horoiomuy6xignjv, qty3gmiq3zhs7whorla4ynvmndp...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                                 [6tert2z5hydswwvt]
# 1334                                 [mldozg3tw4qyzavm]
#
#                                                     url  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                              [he22pncoselnm54h.onion]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                              [darkfailllnkf4vf.onion]
# 4                              [rvy6qmlqfstv6rlz.onion]
# ...                                                 ...
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1331  [horoiomuy6xignjv.onion, qty3gmiq3zhs7whorla4y...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                           [6tert2z5hydswwvt.onion]
# 1334  [mldozg3tw4qyzavm.onion, mldozg3tw4qyzavm.onio...
#
#                                                   title  \
# 0                                    [! CLONED CARDS !]
# 1                    [$$ The Green Machine $$ - Error ]
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [&#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&...
# 4     [&lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dre...
# ...                                                 ...
# 1330                                              [淡路島]
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]
# 1332                                             [茶马古道]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
# 1334  [��� ����� � ������� - The Front Page, ��� ���...
#
#                                               body_text  \
# 0     [! CLONED CARDS !, Home, Price, Shipping, Ques...
# 1     [$$ The Green Machine $$ - Error You have been...
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [d﻿ark.fai﻿l: Which darknet sites are online?,...
# 4     [<<</>> Chaos Computer Club Dresden | c3d2, <<...
# ...                                                 ...
# 1330  [淡路島, 淡路島 - コシニテ人びとへの手紙 -, 玉ねぎを育もう, Update, 20...
# 1331  [约伊兹的萌狼乡手札, vertical_align_top重新开始？🙃, menu, 约伊...
# 1332                   [茶马古道, 茶马护盾已开启欢迎来到茶马古道，页面跳转中...]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
# 1334  [��� ����� � ������� - The Front Page, ������,...
#
#                                              body_token  \
# 0     [clone, card, home, price, ship, question, con...
# 1       [machin, error, log, session, ha, expir, pleas]
# 2     [credit, card, wester, union, moneygram, accou...
# 3     [ark, darknet, site, onlin, darknet, site, onl...
# 4     [chao, comput, club, dresden, chao, comput, cl...
# ...                                                 ...
# 1330  [淡路島, 淡路島, コシニテ人びとへの手紙, 玉ねぎを育もう, updat, scale,...
# 1331  [约伊兹的萌狼乡手札, menu, 约伊兹的萌狼乡手札, more_vert, ホロ, 且被...
# 1332                     [茶马古道, 茶马护盾已开启欢迎来到茶马古道, 页面跳转中]
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]
# 1334  [page, admin, cm, articl, onion, tor, browser,...
#
#                                             title_token  language
# 0                                         [clone, card]      [en]
# 1                                       [machin, error]      [en]
# 2     [credit, card, wester, union, moneygram, accou...      [en]
# 3                                [darknet, site, onlin]      [en]
# 4     [lt, lt, lt, gt, gt, chao, comput, club, dresden]      [en]
# ...                                                 ...       ...
# 1330                                              [淡路島]      [ja]
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]  [en, en]
# 1332                                             [茶马古道]      [ko]
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]      [ko]
# 1334                                         [page, cm]      [en]
#
# [1335 rows x 8 columns]

# %%
df_test['language'] = df_test['language'].apply(lambda x: most_frequent(x))
df_test
# Out:
#                                            cluster_name  \
# 0                                      ! CLONED CARDS !
# 1                       $$ The Green Machine $$ - Error
# 2     $$$ Credit Cards | PayPal | Wester Union | Mon...
# 3     &#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&#...
# 4     &lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dres...
# ...                                                 ...
# 1330                                                淡路島
# 1331                                          约伊兹的萌狼乡手札
# 1332                                               茶马古道
# 1333                    藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉
# 1334               ��� ����� � ������� - The Front Page
#
#                                                  domain  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                                    [he22pncoselnm54h]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                                    [darkfailllnkf4vf]
# 4                                    [rvy6qmlqfstv6rlz]
# ...                                                 ...
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1331  [horoiomuy6xignjv, qty3gmiq3zhs7whorla4ynvmndp...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                                 [6tert2z5hydswwvt]
# 1334                                 [mldozg3tw4qyzavm]
#
#                                                     url  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                              [he22pncoselnm54h.onion]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                              [darkfailllnkf4vf.onion]
# 4                              [rvy6qmlqfstv6rlz.onion]
# ...                                                 ...
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1331  [horoiomuy6xignjv.onion, qty3gmiq3zhs7whorla4y...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                           [6tert2z5hydswwvt.onion]
# 1334  [mldozg3tw4qyzavm.onion, mldozg3tw4qyzavm.onio...
#
#                                                   title  \
# 0                                    [! CLONED CARDS !]
# 1                    [$$ The Green Machine $$ - Error ]
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [&#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&...
# 4     [&lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dre...
# ...                                                 ...
# 1330                                              [淡路島]
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]
# 1332                                             [茶马古道]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
# 1334  [��� ����� � ������� - The Front Page, ��� ���...
#
#                                               body_text  \
# 0     [! CLONED CARDS !, Home, Price, Shipping, Ques...
# 1     [$$ The Green Machine $$ - Error You have been...
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [d﻿ark.fai﻿l: Which darknet sites are online?,...
# 4     [<<</>> Chaos Computer Club Dresden | c3d2, <<...
# ...                                                 ...
# 1330  [淡路島, 淡路島 - コシニテ人びとへの手紙 -, 玉ねぎを育もう, Update, 20...
# 1331  [约伊兹的萌狼乡手札, vertical_align_top重新开始？🙃, menu, 约伊...
# 1332                   [茶马古道, 茶马护盾已开启欢迎来到茶马古道，页面跳转中...]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
# 1334  [��� ����� � ������� - The Front Page, ������,...
#
#                                              body_token  \
# 0     [clone, card, home, price, ship, question, con...
# 1       [machin, error, log, session, ha, expir, pleas]
# 2     [credit, card, wester, union, moneygram, accou...
# 3     [ark, darknet, site, onlin, darknet, site, onl...
# 4     [chao, comput, club, dresden, chao, comput, cl...
# ...                                                 ...
# 1330  [淡路島, 淡路島, コシニテ人びとへの手紙, 玉ねぎを育もう, updat, scale,...
# 1331  [约伊兹的萌狼乡手札, menu, 约伊兹的萌狼乡手札, more_vert, ホロ, 且被...
# 1332                     [茶马古道, 茶马护盾已开启欢迎来到茶马古道, 页面跳转中]
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]
# 1334  [page, admin, cm, articl, onion, tor, browser,...
#
#                                             title_token language
# 0                                         [clone, card]       en
# 1                                       [machin, error]       en
# 2     [credit, card, wester, union, moneygram, accou...       en
# 3                                [darknet, site, onlin]       en
# 4     [lt, lt, lt, gt, gt, chao, comput, club, dresden]       en
# ...                                                 ...      ...
# 1330                                              [淡路島]       ja
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]       en
# 1332                                             [茶马古道]       ko
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]       ko
# 1334                                         [page, cm]       en
#
# [1335 rows x 8 columns]

# %%
df_test_eng = df_test[df_test['language'] == 'en']
df_test_eng
# Out:
#                                            cluster_name  \
# 0                                      ! CLONED CARDS !
# 1                       $$ The Green Machine $$ - Error
# 2     $$$ Credit Cards | PayPal | Wester Union | Mon...
# 3     &#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&#...
# 4     &lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dres...
# ...                                                 ...
# 1304                                       | TheYOSH.nl
# 1321                            ✉ Guerrilla Mail on Tor
# 1322  ✔ Legit Carding Services ♛ Money Transfer Worl...
# 1331                                          约伊兹的萌狼乡手札
# 1334               ��� ����� � ������� - The Front Page
#
#                                                  domain  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                                    [he22pncoselnm54h]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                                    [darkfailllnkf4vf]
# 4                                    [rvy6qmlqfstv6rlz]
# ...                                                 ...
# 1304                                 [ctzzqqimlfamyhrc]
# 1321                                 [grrmailb3fxpjbwm]
# 1322                                 [greenegbqkyk3ois]
# 1331  [horoiomuy6xignjv, qty3gmiq3zhs7whorla4ynvmndp...
# 1334                                 [mldozg3tw4qyzavm]
#
#                                                     url  \
# 0     [mhcge66dpacblyp55fv2i7bf37qg22xe34b4hcz2vyxpk...
# 1                              [he22pncoselnm54h.onion]
# 2     [2cardsowr7u7uvpyrnc5lxuclhb4noj6q2cqf2so7ezg2...
# 3                              [darkfailllnkf4vf.onion]
# 4                              [rvy6qmlqfstv6rlz.onion]
# ...                                                 ...
# 1304                           [ctzzqqimlfamyhrc.onion]
# 1321                           [grrmailb3fxpjbwm.onion]
# 1322                           [greenegbqkyk3ois.onion]
# 1331  [horoiomuy6xignjv.onion, qty3gmiq3zhs7whorla4y...
# 1334  [mldozg3tw4qyzavm.onion, mldozg3tw4qyzavm.onio...
#
#                                                   title  \
# 0                                    [! CLONED CARDS !]
# 1                    [$$ The Green Machine $$ - Error ]
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [&#x64;&#65279;&#x61;&#x72;&#x6B;&#x2E;&#x66;&...
# 4     [&lt;&lt;&lt;/&gt;&gt; Chaos Computer Club Dre...
# ...                                                 ...
# 1304                                     [| TheYOSH.nl]
# 1321                          [✉ Guerrilla Mail on Tor]
# 1322  [✔ Legit Carding Services ♛ Money Transfer Wor...
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]
# 1334  [��� ����� � ������� - The Front Page, ��� ���...
#
#                                               body_text  \
# 0     [! CLONED CARDS !, Home, Price, Shipping, Ques...
# 1     [$$ The Green Machine $$ - Error You have been...
# 2     [$$$ Credit Cards | PayPal | Wester Union | Mo...
# 3     [d﻿ark.fai﻿l: Which darknet sites are online?,...
# 4     [<<</>> Chaos Computer Club Dresden | c3d2, <<...
# ...                                                 ...
# 1304  [| TheYOSH.nl, Skip to main content, User acco...
# 1321  [✉ Guerrilla Mail on Tor, TorGuerrillaMail - D...
# 1322  [✔ Legit Carding Services ♛ Money Transfer Wor...
# 1331  [约伊兹的萌狼乡手札, vertical_align_top重新开始？🙃, menu, 约伊...
# 1334  [��� ����� � ������� - The Front Page, ������,...
#
#                                              body_token  \
# 0     [clone, card, home, price, ship, question, con...
# 1       [machin, error, log, session, ha, expir, pleas]
# 2     [credit, card, wester, union, moneygram, accou...
# 3     [ark, darknet, site, onlin, darknet, site, onl...
# 4     [chao, comput, club, dresden, chao, comput, cl...
# ...                                                 ...
# 1304  [theyosh, nl, skip, content, user, account, me...
# 1321  [guerrilla, mail, tor, dispos, mail, address, ...
# 1322  [card, servic, money, transfer, worldwid, webs...
# 1331  [约伊兹的萌狼乡手札, menu, 约伊兹的萌狼乡手札, more_vert, ホロ, 且被...
# 1334  [page, admin, cm, articl, onion, tor, browser,...
#
#                                             title_token language
# 0                                         [clone, card]       en
# 1                                       [machin, error]       en
# 2     [credit, card, wester, union, moneygram, accou...       en
# 3                                [darknet, site, onlin]       en
# 4     [lt, lt, lt, gt, gt, chao, comput, club, dresden]       en
# ...                                                 ...      ...
# 1304                                      [theyosh, nl]       en
# 1321                             [guerrilla, mail, tor]       en
# 1322  [card, servic, money, transfer, worldwid, webs...       en
# 1331                             [约伊兹的萌狼乡手札, 约伊兹的萌狼乡手札]       en
# 1334                                         [page, cm]       en
#
# [1167 rows x 8 columns]

# %%
df_test_noneng = df_test[df_test['language'] != 'en']
df_test_noneng
# Out:
#                                            cluster_name  \
# 6     *** JES 2020 *** Кшись и Компания. Частное рад...
# 22                                                24BOT
# 23                                             2channel
# 53                                              Accueil
# 56                              Adult puzzle ~ Galleria
# ...                                                 ...
# 1328                                         暗网中文担保交易市场
# 1329               暗网中文担保交易市场 - 一个小高端中文安全买卖平台暗网中文担保交易市场
# 1330                                                淡路島
# 1332                                               茶马古道
# 1333                    藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉
#
#                                                  domain  \
# 6     [73ovw2epsc4kga45lhz4sm3ulfzemdzlhxlj6p2b7i4py...
# 22                                   [24boths2mh6sxaz5]
# 23                                   [2chagyntyms53ruy]
# 53                                   [djypjjvw532evfw3]
# 56                                   [2adud6uuxl2tg7aj]
# ...                                                 ...
# 1328                                 [txxh3pmeihpcw4pe]
# 1329               [m6onsfnvo4iolyix, moi3v3c77y5ckdsh]
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                                 [6tert2z5hydswwvt]
#
#                                                     url  \
# 6     [73ovw2epsc4kga45lhz4sm3ulfzemdzlhxlj6p2b7i4py...
# 22                             [24boths2mh6sxaz5.onion]
# 23                             [2chagyntyms53ruy.onion]
# 53                             [djypjjvw532evfw3.onion]
# 56                             [2adud6uuxl2tg7aj.onion]
# ...                                                 ...
# 1328                           [txxh3pmeihpcw4pe.onion]
# 1329  [m6onsfnvo4iolyix.onion, moi3v3c77y5ckdsh.onio...
# 1330  [a5h4uuqoovwvcbiecjkjlu7ew7z4lszfv67dodqol2ive...
# 1332  [7zj4oshsyhokgus6fyk7pmdiubu4mkjpjjprjkvopnhnw...
# 1333                           [6tert2z5hydswwvt.onion]
#
#                                                   title  \
# 6     [*** JES 2020 *** Кшись и Компания. Частное ра...
# 22                                              [24BOT]
# 23                                           [2channel]
# 53                                            [Accueil]
# 56                            [Adult puzzle ~ Galleria]
# ...                                                 ...
# 1328                                       [暗网中文担保交易市场]
# 1329  [暗网中文担保交易市场 - 一个小高端中文安全买卖平台暗网中文担保交易市场, 暗网中文担保交...
# 1330                                              [淡路島]
# 1332                                             [茶马古道]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
#
#                                               body_text  \
# 6     [*** JES 2020 *** Кшись и Компания. Частное ра...
# 22    [24BOT, 24boths2mh6sxaz5.onion - моментальный ...
# 23    [2channel, 2channel.moe, Добро пожаловать., О ...
# 53    [Accueil, Accueil, Produits, Contact/Commande,...
# 56    [Adult puzzle ~ Galleria, Adult puzzle ~ Galle...
# ...                                                 ...
# 1328  [暗网中文担保交易市场, 本市场并无分号，独此一家，其他均为假冒。价格显示为美元，支付结算时...
# 1329  [暗网中文担保交易市场 - 一个小高端中文安全买卖平台暗网中文担保交易市场, 本市场独此一家...
# 1330  [淡路島, 淡路島 - コシニテ人びとへの手紙 -, 玉ねぎを育もう, Update, 20...
# 1332                   [茶马古道, 茶马护盾已开启欢迎来到茶马古道，页面跳转中...]
# 1333                  [藤原太一 犯罪者 窃盗 脅迫 たかり 亘心綜合音楽事務所 太眉]
#
#                                              body_token  \
# 6     [je, кшись, компания, частное, радио, телевиде...
# 22    [bot, mh, sxaz, onion, моментальный, магазин, ...
# 23    [channel, channel, moe, добро, пожаловать, общ...
# 53    [accueil, accueil, produit, contact, command, ...
# 56    [adult, puzzl, galleria, adult, puzzl, galleri...
# ...                                                 ...
# 1328  [暗网中文担保交易市场, 独此一家, 其他均为假冒, 价格显示为美元, 支付结算时将转换为比...
# 1329  [暗网中文担保交易市场, 其他均为假冒, 价格显示为美元, 支付结算时将转换为比特币, 莱特...
# 1330  [淡路島, 淡路島, コシニテ人びとへの手紙, 玉ねぎを育もう, updat, scale,...
# 1332                     [茶马古道, 茶马护盾已开启欢迎来到茶马古道, 页面跳转中]
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]
#
#                                             title_token language
# 6     [je, кшись, компания, частное, радио, телевиде...       ru
# 22                                                [bot]       ru
# 23                                            [channel]       ru
# 53                                            [accueil]       fr
# 56                             [adult, puzzl, galleria]       ro
# ...                                                 ...      ...
# 1328                                       [暗网中文担保交易市场]    zh-cn
# 1329  [暗网中文担保交易市场, 暗网中文担保交易市场, 关于春节期间安排的通知, 买家规则, 担保...    zh-cn
# 1330                                              [淡路島]       ja
# 1332                                             [茶马古道]       ko
# 1333                  [犯罪者, 窃盗, 脅迫, たかり, 亘心綜合音楽事務所, 太眉]       ko
#
# [168 rows x 8 columns]

# %%
df_train.to_csv("../data/trainset.csv")
df_test.to_csv("../data/testset.csv")
